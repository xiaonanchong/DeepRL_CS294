# %%
! python train_pg.py gym_energyplus:EnergyPlus-v0
# Out:
# /home/hchonglondon/.local/lib/python3.5/site-packages/requests/__init__.py:83: RequestsDependencyWarning: Old version of cryptography ([1, 3]) may cause slowdown.
#   warnings.warn(warning, RequestsDependencyWarning)
# Running experiment with seed 1
# Logging data to data/vpg_gym_energyplus:EnergyPlus-v0_29-06-2019_14-26-39/1/log.txt
# ********** Iteration 0 ************
# Starting new environment
# start_instance(): idx=0, model_file=/home/hchonglondon/rl-testbed-for-energyplus/EnergyPlus/Model/2ZoneDataCenterHVAC_wEconomizer_Temp_Fan.idf
# start_instance(): weather_files[0]=/usr/local/EnergyPlus-8-8-0/WeatherData/USA_CA_San.Francisco.Intl.AP.724940_TMY3.epw
# Starting EnergyPlus with command: /usr/local/EnergyPlus-8-8-0/energyplus -r -x -d log/output/episode-00000000 -w log/output/episode-00000000/USA_CA_San.Francisco.Intl.AP.724940_TMY3.epw log/output/episode-00000000/2ZoneDataCenterHVAC_wEconomizer_Temp_Fan.idf
# PipeIo.readline: Opening OBS pipe [/tmp/extctrl_25002_obs]
# ...

# %%
! python train_pg.py CartPole-v0
# Out:
# /home/hchonglondon/.local/lib/python3.5/site-packages/requests/__init__.py:83: RequestsDependencyWarning: Old version of cryptography ([1, 3]) may cause slowdown.
#   warnings.warn(warning, RequestsDependencyWarning)
# Running experiment with seed 1
# Logging data to data/vpg_CartPole-v0_29-06-2019_14-24-47/1/log.txt
# ********** Iteration 0 ************
# train_pg.py:215: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   sy_probs = F.softmax(sy_logit)
# average_rewards :  18.6
#
#
# /home/hchonglondon/.local/lib/python3.5/site-packages/torch/nn/_reduction.py:46: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# ----------------------------------------
# |               Time |           0.663 |
# |          Iteration |               0 |
# |      AverageReturn |            18.6 |
# |          StdReturn |            8.86 |
# ...

# %%
! python train_pg.py CartPole-v0 -n 100 -b 1000 -e 3 -dna --exp_name sb_no_rtg_dna
# Out:
# /home/hchonglondon/.local/lib/python3.5/site-packages/requests/__init__.py:83: RequestsDependencyWarning: Old version of cryptography ([1, 3]) may cause slowdown.
#   warnings.warn(warning, RequestsDependencyWarning)
# Running experiment with seed 1
# Logging data to data/sb_no_rtg_dna_CartPole-v0_29-06-2019_15-02-46/1/log.txt
# ********** Iteration 0 ************
# train_pg.py:215: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   sy_probs = F.softmax(sy_logit)
# average_rewards :  18.6
#
#
# /home/hchonglondon/.local/lib/python3.5/site-packages/torch/nn/_reduction.py:46: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# ----------------------------------------
# |               Time |             0.2 |
# |          Iteration |               0 |
# |      AverageReturn |            18.6 |
# ...

# %%
! python train_pg.py gym_energyplus:EnergyPlus-v0 -n 100 -b 1000 -e 3 -dna --exp_name sb_no_rtg_dna --ep 100
# Out:
# /home/hchonglondon/.local/lib/python3.5/site-packages/requests/__init__.py:83: RequestsDependencyWarning: Old version of cryptography ([1, 3]) may cause slowdown.
#   warnings.warn(warning, RequestsDependencyWarning)
# Running experiment with seed 1
# Logging data to data/sb_no_rtg_dna_gym_energyplus:EnergyPlus-v0_29-06-2019_15-10-17/1/log.txt
# ********** Iteration 0 ************
# Starting new environment
# start_instance(): idx=0, model_file=/home/hchonglondon/rl-testbed-for-energyplus/EnergyPlus/Model/2ZoneDataCenterHVAC_wEconomizer_Temp_Fan.idf
# start_instance(): weather_files[0]=/usr/local/EnergyPlus-8-8-0/WeatherData/USA_CA_San.Francisco.Intl.AP.724940_TMY3.epw
# Starting EnergyPlus with command: /usr/local/EnergyPlus-8-8-0/energyplus -r -x -d log/output/episode-00000000 -w log/output/episode-00000000/USA_CA_San.Francisco.Intl.AP.724940_TMY3.epw log/output/episode-00000000/2ZoneDataCenterHVAC_wEconomizer_Temp_Fan.idf
# ...

# %%
! pip install seaborn
# Out:
# ...
#     100% |████████████████████████████████| 215kB 4.6MB/s
# ...
# You are using pip version 8.1.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# %matplotlib inline
! python plot.py data/sb_no_rtg_dna_gym_energyplus:EnergyPlus-v0_29-06-2019_15-10-17 --value AverageReturn
# Out:
# plot.py:72: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   experiment_data = pd.read_table(log_path)
# /home/hchonglondon/anaconda3/lib/python3.5/site-packages/seaborn/timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
! python train_pg.py gym_energyplus:EnergyPlus-v0 -n 500 -b 1000 -e 3 -rtg --exp_name test1 --ep 200
# Out:
# /home/hchonglondon/.local/lib/python3.5/site-packages/requests/__init__.py:83: RequestsDependencyWarning: Old version of cryptography ([1, 3]) may cause slowdown.
#   warnings.warn(warning, RequestsDependencyWarning)
# Running experiment with seed 1
# Logging data to data/test1_gym_energyplus:EnergyPlus-v0_29-06-2019_18-36-41/1/log.txt
# ********** Iteration 0 ************
# Starting new environment
# start_instance(): idx=0, model_file=/home/hchonglondon/rl-testbed-for-energyplus/EnergyPlus/Model/2ZoneDataCenterHVAC_wEconomizer_Temp_Fan.idf
# start_instance(): weather_files[0]=/usr/local/EnergyPlus-8-8-0/WeatherData/USA_CA_San.Francisco.Intl.AP.724940_TMY3.epw
# Starting EnergyPlus with command: /usr/local/EnergyPlus-8-8-0/energyplus -r -x -d log/output/episode-00000000 -w log/output/episode-00000000/USA_CA_San.Francisco.Intl.AP.724940_TMY3.epw log/output/episode-00000000/2ZoneDataCenterHVAC_wEconomizer_Temp_Fan.idf
# PipeIo.readline: Opening OBS pipe [/tmp/extctrl_9880_obs]
# ...

# %%
! python plot.py data/test1_gym_energyplus:EnergyPlus-v0_29-06-2019_18-36-41 --value AverageReturn
    
#image saved as cxnexp1.
# Out:
# plot.py:72: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   experiment_data = pd.read_table(log_path)
# /home/hchonglondon/anaconda3/lib/python3.5/site-packages/seaborn/timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# experiment 1: do not normalize advantages; no reward to go
# episode length = one month
# batch size = 1000
# number of iteration = 100

# %%
! python train_pg.py gym_energyplus:EnergyPlus-v0 -n 100 -b 1000 -e 3 -dna --exp_name experiment1 --ep 2880
# Out:
# /home/hchonglondon/.local/lib/python3.5/site-packages/requests/__init__.py:83: RequestsDependencyWarning: Old version of cryptography ([1, 3]) may cause slowdown.
#   warnings.warn(warning, RequestsDependencyWarning)
# Running experiment with seed 1
# Logging data to data/experiment1_gym_energyplus:EnergyPlus-v0_01-07-2019_16-51-50/1/log.txt
# ********** Iteration 0 ************
# Starting new environment
# start_instance(): idx=0, model_file=/home/hchonglondon/rl-testbed-for-energyplus/EnergyPlus/Model/2ZoneDataCenterHVAC_wEconomizer_Temp_Fan.idf
# start_instance(): weather_files[0]=/usr/local/EnergyPlus-8-8-0/WeatherData/USA_CA_San.Francisco.Intl.AP.724940_TMY3.epw
# Starting EnergyPlus with command: /usr/local/EnergyPlus-8-8-0/energyplus -r -x -d log/output/episode-00000000 -w log/output/episode-00000000/USA_CA_San.Francisco.Intl.AP.724940_TMY3.epw log/output/episode-00000000/2ZoneDataCenterHVAC_wEconomizer_Temp_Fan.idf
# PipeIo.readline: Opening OBS pipe [/tmp/extctrl_1719_obs]
# ...

# %%
! python plot.py data/experiment1_gym_energyplus:EnergyPlus-v0_01-07-2019_16-51-50 --value AverageReturn
    
#image saved as experiment1.
# Out:
# plot.py:72: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   experiment_data = pd.read_table(log_path)
# /home/hchonglondon/anaconda3/lib/python3.5/site-packages/seaborn/timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# experiment 2: do not normalize advantages; no reward to go episode length = one month batch size = 1000 number of iteration = 1000

# %%
! python train_pg.py gym_energyplus:EnergyPlus-v0 -n 1000 -b 1000 -e 3 -dna --exp_name experiment1 --ep 2880
# Out:
# /home/hchonglondon/.local/lib/python3.5/site-packages/requests/__init__.py:83: RequestsDependencyWarning: Old version of cryptography ([1, 3]) may cause slowdown.
#   warnings.warn(warning, RequestsDependencyWarning)
# Running experiment with seed 1
# Logging data to data/experiment1_gym_energyplus:EnergyPlus-v0_01-07-2019_17-45-43/1/log.txt
# ********** Iteration 0 ************
# Starting new environment
# start_instance(): idx=0, model_file=/home/hchonglondon/rl-testbed-for-energyplus/EnergyPlus/Model/2ZoneDataCenterHVAC_wEconomizer_Temp_Fan.idf
# start_instance(): weather_files[0]=/usr/local/EnergyPlus-8-8-0/WeatherData/USA_CA_San.Francisco.Intl.AP.724940_TMY3.epw
# Starting EnergyPlus with command: /usr/local/EnergyPlus-8-8-0/energyplus -r -x -d log/output/episode-00000000 -w log/output/episode-00000000/USA_CA_San.Francisco.Intl.AP.724940_TMY3.epw log/output/episode-00000000/2ZoneDataCenterHVAC_wEconomizer_Temp_Fan.idf
# PipeIo.readline: Opening OBS pipe [/tmp/extctrl_5375_obs]
# ...
